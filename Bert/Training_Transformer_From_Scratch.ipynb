# %% [markdown]
# # Bert

# %% [markdown]
# ### Bert 소개
#
# * Transformer의 encoder 부분만 활용
# * NLP 분야에 Fine-Tuning 개념 도입
# * Masked Language Model[MLM] 뿐만아니라 Next Sentence Prediction[NSP]를 통해 학습
#
# <br/>
#
# **Next Sentence Prediction** 이해하기
#
# * 이전 문장이 현재 문장과 연속적인 내용인지를 판단하는 binary classification

# %%
from konlpy.tag import Okt,Hannanum
import pandas as pd

books = pd.read_csv('./data/bookinfo.csv', index_col=0)

book_list = books.iloc[:1000,2:]

okt = Okt()

# %%
def list_to_string(ist:list) -> str :
    type_to_str = list(map(str,ist))
    word = ''.join(type_to_str)
    return word

word_list = [list_to_string(ist[1].tolist()) for ist in book_list.iterrows()]

# %%
han = Hannanum()
corpus = [han.morphs(word) for word in word_list]
# Out:
# java.lang.ArrayIndexOutOfBoundsException: Index 10000 out of bounds for length 10000
# 	at kr.ac.kaist.swrc.jhannanum.plugin.MajorPlugin.PosTagger.HmmPosTagger.HMMTagger.new_mnode(HMMTagger.java:354)
# 	at kr.ac.kaist.swrc.jhannanum.plugin.MajorPlugin.PosTagger.HmmPosTagger.HMMTagger.tagPOS(HMMTagger.java:143)
# 	at kr.ac.kaist.swrc.jhannanum.hannanum.Workflow.analyzeInSingleThread(Workflow.java:857)
# 	at kr.ac.kaist.swrc.jhannanum.hannanum.Workflow.analyze(Workflow.java:521)
# 	at kr.lucypark.jhannanum.comm.HannanumInterface.simplePos09(Unknown Source)
# java.lang.ArrayIndexOutOfBoundsException
# java.lang.ArrayIndexOutOfBoundsException
# java.lang.ArrayIndexOutOfBoundsException

# %%
a = pd.DataFrame(corpus)
1000-sum(a.iloc[:,3000].isna())
# Out:
# 137

# %%
import torch

tensor_corpus = torch.tensor(pd.DataFrame(corpus))

tensor_corpus[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/yangwoolee/git_repo/Deep_learning_from_scratch/Bert/Training_Transformer_From_Scratch.ipynb 셀 6 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/yangwoolee/git_repo/Deep_learning_from_scratch/Bert/Training_Transformer_From_Scratch.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> import torch
# ----> <a href='vscode-notebook-cell:/Users/yangwoolee/git_repo/Deep_learning_from_scratch/Bert/Training_Transformer_From_Scratch.ipynb#X21sZmlsZQ%3D%3D?line=2'>3</a> tensor_corpus = torch.tensor(pd.DataFrame(corpus))
#       <a href='vscode-notebook-cell:/Users/yangwoolee/git_repo/Deep_learning_from_scratch/Bert/Training_Transformer_From_Scratch.ipynb#X21sZmlsZQ%3D%3D?line=4'>5</a> tensor_corpus[0]
#
# ValueError: too many dimensions 'str'

# %%
len(set(a))
# Out:
# 45756

# %%
def TextEncoding() :
    def __init__(self, word_corpus) :
        self.pad_token = "[PAD]"
        self.unk_token = "[UNK]"

        token_to_id = {}
        id_to_token = {}
# Out:
# ['소프트웨어',
#  '개발',
#  '예전',
#  '개발자',
#  '로서',
#  '지속',
#  '변화',
#  '기술',
#  '트렌드',
#  '뿐',
#  '소프트웨어',
#  '이면',
#  '비즈니스',
#  '도메인',
#  '이해해',
#  '이',
#  '실용',
#  '비즈니스',
#  '도메인',
#  '분석',
#  '비즈니스',
#  '전략',
#  '이해',
#  '것',
#  '무엇',
#  '비즈니스',
#  '요건',
#  '소프트웨어',
#  '설계',
#  '조정',
#  '위',
#  '일련',
#  '핵심',
#  '패턴',
#  '원리',
#  '실천',
#  '법',
#  '저자',
#  '실무',
#  '통해',
#  '비즈니스',
#  '로직',
#  '구현',
#  '미래',
#  '지향',
#  '소프트웨어',
#  '설계',
#  '아키텍처',
#  '독자',
#  '비즈니스',
#  '요구사항',
#  '충족',
#  '아키텍처',
#  '의사결정',
#  '리기',
#  '위',
#  '도메인',
#  '주도',
#  '설계',
#  '다른',
#  '방법론',
#  '관계',
#  '검토',
#  '것',
#  '또한',
#  '스타트업',
#  '를',
#  '구현',
#  '실제',
#  '실무',
#  '사례',
#  '것',
#  '이',
#  '책',
#  '내용',
#  '개발',
#  '시스템',
#  '회사',
#  '경쟁',
#  '전략',
#  '부합',
#  '위해',
#  '회사',
#  '비즈니스',
#  '도메인',
#  '분석',
#  '방법',
#  '비즈니스',
#  '요건',
#  '충족',
#  '효과',
#  '소프트웨어',
#  '솔루션',
#  '설계',
#  '위해',
#  '의',
#  '전략',
#  '전술',
#  '도구',
#  '사용',
#  '방법',
#  '당면',
#  '비즈니스',
#  '도메인',
#  '대한',
#  '공동',
#  '이해',
#  '법',
#  '시스템',
#  '바운디드',
#  '컨',
#  '텍스트',
#  '분해',
#  '법',
#  '브라운필드',
#  '프로젝트',
#  '를',
#  '점진',
#  '도입',
#  '법',
#  '전략',
#  '설계',
#  '장',
#  '비즈니스',
#  '도메인',
#  '분석',
#  '비즈니스',
#  '도메인',
#  '하위',
#  '도메인',
#  '하위',
#  '도메인',
#  '유형',
#  '하위',
#  '도메인',
#  '비교',
#  '하위',
#  '도메인',
#  '경계',
#  '식별',
#  '도메인',
#  '분석',
#  '예제',
#  '도메인',
#  '전문가',
#  '사람',
#  '결론',
#  '연습',
#  '문제',
#  '장',
#  '도메인',
#  '지식',
#  '비즈니스',
#  '문제',
#  '도메인',
#  '지식',
#  '커뮤니케이션',
#  '유비쿼터스',
#  '어란',
#  '무엇',
#  '비즈니스',
#  '언어',
#  '시나리오',
#  '관성',
#  '비즈니스',
#  '도메인',
#  '모델',
#  '모델',
#  '무엇',
#  '효과',
#  '모델링',
#  '비즈니스',
#  '도메인',
#  '모델링',
#  '지속',
#  '노력',
#  '도구',
#  '도전',
#  '과제',
#  '결론',
#  '연습',
#  '문제',
#  '장',
#  '도메인',
#  '복잡',
#  '관리',
#  '관성',
#  '모델',
#  '바운디드',
#  '컨',
#  '텍스트',
#  '란',
#  '무엇',
#  '모델',
#  '경계',
#  '정제',
#  '유비쿼터스',
#  '언어',
#  '바운디드',
#  '컨',
#  '텍스트',
#  '범위',
#  '바운디드',
#  '컨',
#  '텍스트',
#  '하위',
#  '도메인',
#  '하위',
#  '도메인',
#  '바운디드',
#  '컨',
#  '텍스트',
#  '하위',
#  '도메인',
#  '바운디드',
#  '컨',
#  '텍스트',
#  '사이',
#  '상호작용',
#  '경계',
#  '물리',
#  '경계',
#  '소유권',
#  '경계',
#  '실생활',
#  '바운디드',
#  '컨',
#  '텍스트',
#  '맨',
#  '도메인',
#  '과학',
#  '냉장고',
#  '구입',
#  '결론',
#  '연습',
#  '문제',
#  '장',
#  '바운디드',
#  '컨',
#  '텍스트',
#  '연동',
#  '협력',
#  '패턴',
#  '그룹',
#  '파트너',
#  '패턴',
#  '공유',
#  '커널',
#  '패턴',
#  '사용자',
#  '제공',
#  '패턴',
#  '그룹',
#  '순응',
#  '주의자',
#  '패턴',
#  '충돌',
#  '방지',
#  '계층',
#  '패턴',
#  '오픈',
#  '호스트',
#  '서비스',
#  '패턴',
#  '분리',
#  '노선',
#  '커뮤니케이션',
#  '이슈',
#  '일반',
#  '하위',
#  '도메인',
#  '모델',
#  '차이',
#  '컨',
#  '텍스트',
#  '맵',
#  '유지',
#  '보수',
#  '한계',
#  '결론',
#  '연습',
#  '문제',
#  '전술',
#  '설계',
#  '장',
#  '비즈니스',
#  '로직',
#  '구현',
#  '트랜잭션',
#  '스크립트',
#  '구현',
#  '트랜잭션',
#  '스크립트',
#  '사용',
#  '경우',
#  '액티브',
#  '레코드',
#  '구현',
#  '액티브',
#  '레코드',
#  '사용',
#  '경우',
#  '실용',
#  '접근',
#  '방식',
#  '결론',
#  '연습',
#  '문제',
#  '장',
#  '비즈니스',
#  '로직',
#  '배경',
#  '도메인',
#  '모델',
#  '구현',
#  '구성요소',
#  '복잡',
#  '관리',
#  '결론',
#  '연습',
#  '문제',
#  '장',
#  '시간',
#  '차원',
#  '모델링',
#  '이벤트',
#  '소싱',
#  '검색',
#  '분석',
#  '원천',
#  '데이터',
#  '이벤트',
#  '스토어',
#  '이벤트',
#  '소싱',
#  '도메인',
#  '모델',
#  '장점',
#  '단점',
#  '자주',
#  '질문',
#  '성능',
#  '데이터',
#  '삭제',
#  '요',
#  '결론',
#  '연습',
#  '문제',
#  '장',
#  '아키텍처',
#  '패턴',
#  '비즈니스',
#  '로직',
#  '아키텍처',
#  '패턴',
#  '계층',
#  '아키텍처',
#  '프레',
#  '젠',
#  '테이',
#  '션',
#  '계층',
#  '비즈니스',
#  '로직',
#  '계층',
#  '데이터',
#  '접근',
#  '계층',
#  '계층',
#  '간',
#  '커뮤니케이션',
#  '변종',
#  '계층',
#  '아키텍처',
#  '사용',
#  '경우',
#  '포트',
#  '어댑터',
#  '용어',
#  '의존',
#  '역전',
#  '원칙',
#  '인프라',
#  '구성요소',
#  '연동',
#  '변형',
#  '포트',
#  '어댑터',
#  '사용',
#  '경우',
#  '폴리',
#  '글랏',
#  '모델링',
#  '모델',
#  '프로',
#  '젝션',
#  '도전',
#  '과제',
#  '모델',
#  '분리',
#  '를',
#  '사용',
#  '경우',
#  '범위',
#  '결론',
#  '연습',
#  '문제',
#  '장',
#  '커뮤니케이션',
#  '패턴',
#  '모델',
#  '변환',
#  '스테이',
#  '트리스',
#  '모델',
#  '변환',
#  '스테이',
#  '트풀',
#  '모델',
#  '변환',
#  '애',
#  '게이트',
#  '연동',
#  '아웃',
#  '박스',
#  '사가',
#  '프로세스',
#  '관리자',
#  '결론',
#  '연습',
#  '문제',
#  '도메인',
#  '주도',
#  '설계',
#  '적용',
#  '실무',
#  '장',
#  '휴리스틱',
#  '설계',
#  '휴리스틱',
#  '바운디드',
#  '컨',
#  '텍스트',
#  '비즈니스',
#  '로직',
#  '구현',
#  '패턴',
#  '아키텍처',
#  '패턴',
#  '테스트',
#  '전략',
#  '피라미드',
#  '테스트',
#  '다이아몬드',
#  '테스트',
#  '역전',
#  '피라미드',
#  '테스트',
#  '전술',
#  '설계',
#  '의사결정',
#  '트리',
#  '결론',
#  '연습',
#  '문제',
#  '장',
#  '진화',
#  '설계',
#  '의사결정',
#  '도메인',
#  '변경',
#  '핵심',
#  '일반',
#  '일반',
#  '핵심',
#  '지원',
#  '일반',
#  '지원',
#  '핵심',
#  '핵심',
#  '지원',
#  '일반',
#  '지원',
#  '전략',
#  '설계',
#  '문제',
#  '전술',
#  '설계',
#  '문제',
#  '트랜잭션',
#  '스크립트',
#  '액티브',
#  '레코드',
#  '액티브',
#  '레코드',
#  '도메인',
#  '모델',
#  '도메인',
#  '모델',
#  '이벤트',
#  '소싱',
#  '도메인',
#  '모델',
#  '전환',
#  '과거',
#  '이력',
#  '생',
#  '마이',
#  '그레이',
#  '션',
#  '이벤트',
#  '모델링',
#  '조직',
#  '변화',
#  '파트너',
#  '사용자',
#  '제공',
#  '자로',
#  '사용자',
#  '제공',
#  '분리',
#  '노선',
#  '도메인',
#  '지식',
#  '성장',
#  '하위',
#  '도메인',
#  '바운디드',
#  '컨',
#  '텍스트',
#  '애',
#  '게이트',
#  '결론',
#  '연습',
#  '문제',
#  '장',
#  '이벤트',
#  '스토',
#  '밍',
#  '이벤트',
#  '스토',
#  '밍',
#  '누가',
#  '이벤트',
#  '스토',
#  '밍',
#  '참석',
#  '하나',
#  '이벤트',
#  '스토',
#  '밍',
#  '무엇',
#  '이벤트',
#  '스토',
#  '밍',
#  '과정',
#  '단계',
#  '탐색',
#  '단계',
#  '타임',
#  '라인',
#  '단계',
#  '고충',
#  '점',
#  '단계',
#  '중요',
#  '이벤트',
#  '단계',
#  '커맨드',
#  '단계',
#  '정책',
#  '단계',
#  '모델',
#  '단계',
#  '외부',
#  '시스템',
#  '단계',
#  '애',
#  '게이트',
#  '단계',
#  '바운디드',
#  '컨',
#  '텍스트',
#  '변형',
#  '이벤트',
#  '스토',
#  '밍',
#  '사용',
#  '경우',
#  '진행',
#  '팁',
#  '활',
#  '원격',
#  '이벤트',
#  '스토',
#  '밍',
#  '결론',
#  '연습',
#  '문제',
#  '장',
#  '실무',
#  '도메인',
#  '주도',
#  '설계',
#  '전략',
#  '분석',
#  '비즈니스',
#  '도메인',
#  '이해',
#  '현재',
#  '설계',
#  '탐색',
#  '대화',
#  '전략',
#  '전략',
#  '대화',
#  '전술',
#  '대화',
#  '유비쿼터스',
#  '언어',
#  '육성',
#  '실용',
#  '도메인',
#  '주도',
#  '설계',
#  '도메인',
#  '주도',
#  '설계',
#  '확산',
#  '실무',
#  '활용',
#  '도메인',
#  '주도',
#  '설계',
#  '결론',
#  '연습',
#  '문제',
#  '다른',
#  '방법론',
#  '및',
#  '패턴',
#  '관계',
#  '장',
#  '마이크로',
#  '서비스',
#  '서비스',
#  '란',
#  '무엇',
#  '마이크로',
#  '서비스',
#  '란',
#  '무엇',
#  '서비스',
#  '메서드',
#  '마이크로',
#  '서비스',
#  '설계',
#  '목표',
#  '시스템',
#  '복잡',
#  '서비스',
#  '로서',
#  '마이크로',
#  '서비스',
#  '모듈',
#  '로서',
#  '마이크로',
#  '서비스',
#  '도메인',
#  '주도',
#  '설계',
#  '마이크로',
#  '서비스',
#  '경계',
#  '바운디드',
#  '컨',
#  '텍스트',
#  '애',
#  '게이트',
#  '하위',
#  '도메인',
#  '마이크로',
#  '서비스',
#  '퍼블릭',
#  '인터페이스',
#  '압축',
#  '오픈',
#  '호스트',
#  '서비스',
#  '충돌',
#  '방지',
#  '계층',
#  '결론',
#  '연습',
#  '문제',
#  '장',
#  '이벤트',
#  '주도',
#  '아키텍처',
#  '이벤트',
#  '주도',
#  '아키텍처',
#  '이벤트',
#  '이벤트',
#  '커맨드',
#  '메시지',
#  '구조',
#  '이벤트',
#  '유형',
#  '이벤트',
#  '주도',
#  '연동',
#  '설계',
#  '분산',
#  '진흙',
#  '덩어리',
#  '시간',
#  '결합',
#  '기능',
#  '결합',
#  '구현',
#  '결합',
#  '이벤트',
#  '주도',
#  '연동',
#  '리',
#  '팩터링',
#  '이벤트',
#  '주도',
#  '설계',
#  '휴리스틱',
#  '결론',
#  '연습',
#  '문제',
#  '장',
#  '데이터',
#  '메시',
#  '분석',
#  '데이터',
#  '모델',
#  '트랜잭션',
#  '데이터',
#  '모델',
#  '비교',
#  '팩트',
#  '테이블',
#  '디',
#  '테이블',
#  '분석',
#  '모델',
#  '분석',
#  '데이터',
#  '관리',
#  '플랫폼',
#  '데이터',
#  '웨어하우스',
#  '데이터',
#  '레이크',
#  '데이터',
#  '웨어하우스',
#  '데이터',
#  '레이크',
#  '아키텍처',
#  '도전',
#  '과제',
#  '데이터',
#  '메시',
#  '도메인',
#  '기준',
#  '데이터',
#  '분리',
#  '제품',
#  '관점',
#  '데이터',
#  '자율성',
#  '활성화',
#  '에코',
#  '시스템',
#  '구축',
#  '데이터',
#  '메시',
#  '도메인',
#  '주도',
#  '설계',
#  '엮기',
#  '결론',
#  '연습',
#  '문제',
#  '맺음말',
#  '문제',
#  '솔루션',
#  '구현',
#  '추가',
#  '자료',
#  '고급',
#  '도메인',
#  '주도',
#  '설계',
#  '아키텍처',
#  '및',
#  '통합',
#  '패턴',
#  '레거시',
#  '시스템',
#  '대화',
#  '이벤트',
#  '스토',
#  '밍',
#  '결론',
#  '부록',
#  '적용',
#  '사례',
#  '연구',
#  '다섯',
#  '가지',
#  '바운디드',
#  '컨',
#  '텍스트',
#  '비즈니스',
#  '도메인',
#  '바운디드',
#  '컨',
#  '텍스트',
#  '마케팅',
#  '바운디드',
#  '컨',
#  '텍스트',
#  '바운디드',
#  '컨',
#  '텍스트',
#  '이벤트',
#  '크런처',
#  '바운디드',
#  '컨',
#  '텍스트',
#  '보너스',
#  '바운디드',
#  '컨',
#  '텍스트',
#  '마케팅',
#  '허브',
#  '논의',
#  '유비쿼터스',
#  '언어',
#  '하위',
#  '도메인',
#  '바운디드',
#  '컨',
#  '텍스트',
#  '경계',
#  '결론',
#  '부록',
#  '연습',
#  '문제',
#  '정답']
